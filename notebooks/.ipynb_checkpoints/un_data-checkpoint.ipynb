# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gdp_df = pd.read_csv('../data/gdp.percapita.csv', nrows = 6606)
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  2190.240321              NaN
# 1     Afghanistan  2017  2202.570851              NaN
# 2     Afghanistan  2016  2200.764487              NaN
# 3     Afghanistan  2015  2212.750899              NaN
# 4     Afghanistan  2014  2249.253738              NaN

# %%
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6601        Zimbabwe  1994  3263.934978              NaN
# 6602        Zimbabwe  1993  3033.504852              NaN
# 6603        Zimbabwe  1992  3054.889178              NaN
# 6604        Zimbabwe  1991  3426.598094              NaN
# 6605        Zimbabwe  1990  3324.348171              NaN

# %%
internet_df = pd.read_csv('../data/internet_usage.csv', nrows =4495)
internet_df.head()
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN

# %%
internet_df.tail()
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
internet_df=internet_df.drop(columns= 'Value Footnotes')
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %%
gdp_df = gdp_df.drop(columns= 'Value Footnotes')
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2018  2190.240321
# 1        Afghanistan  2017  2202.570851
# 2        Afghanistan  2016  2200.764487
# 3        Afghanistan  2015  2212.750899
# 4        Afghanistan  2014  2249.253738
# ...              ...   ...          ...
# 6601        Zimbabwe  1994  3263.934978
# 6602        Zimbabwe  1993  3033.504852
# 6603        Zimbabwe  1992  3054.889178
# 6604        Zimbabwe  1991  3426.598094
# 6605        Zimbabwe  1990  3324.348171
#
# [6606 rows x 3 columns]

# %%
internet_df=internet_df.rename(columns = {'Country or Area':'Country','Year':'Year', 'Value':'Internet_Users_Pct'})
internet_df.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
gdp_df=gdp_df.rename(columns = {'Country or Area':'Country','Year':'Year', 'Value':'GDP_Per_Capita'})
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     2190.240321
# 1  Afghanistan  2017     2202.570851
# 2  Afghanistan  2016     2200.764487
# 3  Afghanistan  2015     2212.750899
# 4  Afghanistan  2014     2249.253738

# %%
gdp_and_internet_use = pd.merge(internet_df, gdp_df, 
                               left_on = ['Country', 'Year'], right_on = ['Country' ,'Year'], 
                               how = 'inner')
gdp_and_internet_use
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0     Afghanistan  2014            6.390000     2249.253738
# 1     Afghanistan  2013            5.900000     2264.317575
# 2     Afghanistan  2012            5.454545     2220.481526
# 3     Afghanistan  2011            5.000000     2037.608607
# 4     Afghanistan  2010            4.000000     2093.743565
# ...           ...   ...                 ...             ...
# 3432     Zimbabwe  1997            0.033080     3580.048793
# 3433     Zimbabwe  1996            0.016790     3520.430146
# 3434     Zimbabwe  1995            0.007684     3226.413930
# 3435     Zimbabwe  1994            0.001739     3263.934978
# 3436     Zimbabwe  1990            0.000000     3324.348171
#
# [3437 rows x 4 columns]

# %%
gdp_and_internet_use.tail()
# Out:
#        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 3432  Zimbabwe  1997            0.033080     3580.048793
# 3433  Zimbabwe  1996            0.016790     3520.430146
# 3434  Zimbabwe  1995            0.007684     3226.413930
# 3435  Zimbabwe  1994            0.001739     3263.934978
# 3436  Zimbabwe  1990            0.000000     3324.348171

# %%
gdp_df.shape
# Out:
# (6606, 3)

# %%
internet_df.shape
# Out:
# (4495, 3)

# %%
gdp_and_internet_use
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0     Afghanistan  2014            6.390000     2249.253738
# 1     Afghanistan  2013            5.900000     2264.317575
# 2     Afghanistan  2012            5.454545     2220.481526
# 3     Afghanistan  2011            5.000000     2037.608607
# 4     Afghanistan  2010            4.000000     2093.743565
# ...           ...   ...                 ...             ...
# 3432     Zimbabwe  1997            0.033080     3580.048793
# 3433     Zimbabwe  1996            0.016790     3520.430146
# 3434     Zimbabwe  1995            0.007684     3226.413930
# 3435     Zimbabwe  1994            0.001739     3263.934978
# 3436     Zimbabwe  1990            0.000000     3324.348171
#
# [3437 rows x 4 columns]

# %%
gdp_and_internet_subset = gdp_and_internet_use.query('Year == 2004 or Year == 2009 or Year == 2014')
gdp_and_internet_subset
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0     Afghanistan  2014            6.390000     2249.253738
# 5     Afghanistan  2009            3.550000     1881.777626
# 10    Afghanistan  2004            0.105809     1284.127338
# 13        Albania  2014           60.100000    11828.232264
# 18        Albania  2009           41.200000    10528.778102
# ...           ...   ...                 ...             ...
# 3398       Zambia  2009            6.310000     2917.522504
# 3403       Zambia  2004            2.013550     2261.771409
# 3415     Zimbabwe  2014           19.890000     2955.240287
# 3420     Zimbabwe  2009           11.360000     1925.364381
# 3425     Zimbabwe  2004            6.564045     2480.859342
#
# [479 rows x 4 columns]

# %%
gdp_and_internet_2004 = gdp_and_internet_subset.query('Year == 2004')
gdp_and_internet_2004
gdp_and_internet_2009 = gdp_and_internet_subset.query('Year == 2009')
gdp_and_internet_2009
gdp_and_internet_2014 = gdp_and_internet_subset.query('Year == 2014')
gdp_and_internet_2014
# Out:
#                   Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0             Afghanistan  2014                6.39     2249.253738
# 13                Albania  2014               60.10    11828.232264
# 34                Algeria  2014               18.09    11329.428688
# 56                 Angola  2014               21.26     8239.832077
# 76    Antigua and Barbuda  2014               64.00    18104.241470
# ...                   ...   ...                 ...             ...
# 3330              Uruguay  2014               61.46    20582.168950
# 3352           Uzbekistan  2014               43.55     5764.492705
# 3373              Vanuatu  2014               18.80     3120.545392
# 3393               Zambia  2014               17.34     3450.053831
# 3415             Zimbabwe  2014               19.89     2955.240287
#
# [162 rows x 4 columns]

# %%
max_2004_internet=gdp_and_internet_2004.sort_values('Internet_Users_Pct', ascending=False).head(1)
max_2004_internet
# Out:
#      Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 2964  Sweden  2004               83.89    45029.814344

# %%
min_2004_internet=gdp_and_internet_2004.sort_values('Internet_Users_Pct', ascending=True).head(1)
min_2004_internet
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 2111  Myanmar  2004            0.024337      1696.88176

# %%
max_2009_internet=gdp_and_internet_2009.sort_values('Internet_Users_Pct', ascending=False).head(1)
max_2009_internet
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1365  Iceland  2009                93.0    48428.312438

# %%
min_2009_internet=gdp_and_internet_2009.sort_values('Internet_Users_Pct', ascending=True).head(1)
min_2009_internet
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 3071  Timor-Leste  2009            0.185252     2724.834868

# %%
max_2014_internet=gdp_and_internet_2014.sort_values('Internet_Users_Pct', ascending=False).head(1)
max_2014_internet
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1360  Iceland  2014               98.16    49911.069825

# %%
min_2014_internet=gdp_and_internet_2014.sort_values('Internet_Users_Pct', ascending=True).head(1)
min_2014_internet
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 3066  Timor-Leste  2014                1.14     3264.739189

# %%
max_2014_gdp=gdp_and_internet_2004.sort_values('GDP_Per_Capita', ascending=False).head(1)
max_2014_gdp
# Out:
#          Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1787  Luxembourg  2004               65.88   102850.273309

# %%
min_2014_gdp=gdp_and_internet_2004.sort_values('GDP_Per_Capita', ascending=True).head(1)
min_2014_gdp
# Out:
#      Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1831  Malawi  2004            0.347505      775.346132

# %%
max_2009_gdp=gdp_and_internet_2009.sort_values('GDP_Per_Capita', ascending=False).head(1)
max_2009_gdp
# Out:
#          Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1782  Luxembourg  2009               87.31   105077.951508

# %%
min_2009_gdp=gdp_and_internet_2009.sort_values('GDP_Per_Capita', ascending=True).head(1)
min_2009_gdp
# Out:
#      Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 524  Burundi  2009                 0.9      831.564131

# %%
max_2014_gdp=gdp_and_internet_2014.sort_values('GDP_Per_Capita', ascending=False).head(1)
max_2014_gdp
# Out:
#          Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1777  Luxembourg  2014               94.67   108911.348894

# %%
min_2014_gdp=gdp_and_internet_2014.sort_values('GDP_Per_Capita', ascending=True).head(1)
min_2014_gdp
# Out:
#      Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 519  Burundi  2014                1.38      886.235777

# %%
plt.scatter(x = gdp_and_internet_2004['Internet_Users_Pct'], y =gdp_and_internet_2004['GDP_Per_Capita'],color = 'green')
plt.xlabel('Internet_Use')
plt.ylabel('GDP_Per_capita')
;
# Out:
# ''

# %%
plt.scatter(x = gdp_and_internet_2009['Internet_Users_Pct'], y =gdp_and_internet_2009['GDP_Per_Capita'],color = 'red')
plt.xlabel('Internet_Use')
plt.ylabel('GDP_Per_capita');

# %%
plt.scatter(x = gdp_and_internet_2014['Internet_Users_Pct'], y =gdp_and_internet_2014['GDP_Per_Capita'], color = 'purple')
plt.xlabel('Internet_Use')
plt.ylabel('GDP_Per_capita');

# %%
gdp_and_internet_subset.dtypes
# Out:
# Country                object
# Year                    int64
# Internet_Users_Pct    float64
# GDP_Per_Capita        float64
# dtype: object

# %%
gdp_and_internet_2004.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 10 to 3425
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             156 non-null    object
#  1   Year                156 non-null    int64
#  2   Internet_Users_Pct  156 non-null    float64
#  3   GDP_Per_Capita      156 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.1+ KB

# %%
top_5_gdp_2014 = gdp_and_internet_2014.sort_values('Internet_Users_Pct', ascending=False).head(5)
top_5_gdp_2014
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1360      Iceland  2014               98.16    49911.069825
# 2275       Norway  2014               96.30    61308.763730
# 833       Denmark  2014               95.99    52172.606425
# 1777   Luxembourg  2014               94.67   108911.348894
# 2164  Netherlands  2014               93.17    52432.619199

# %%
top_5_gdp_2009 = gdp_and_internet_2009.sort_values('Internet_Users_Pct', ascending=False).head(5)
top_5_gdp_2009
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1365      Iceland  2009               93.00    48428.312438
# 2280       Norway  2009               92.08    60620.334503
# 2959       Sweden  2009               91.00    46185.526525
# 2169  Netherlands  2009               89.63    51850.500537
# 1782   Luxembourg  2009               87.31   105077.951508

# %%
top_5_gdp_2004 = gdp_and_internet_2004.sort_values('Internet_Users_Pct', ascending=False).head(5)
top_5_gdp_2004
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 2964   Sweden  2004               83.89    45029.814344
# 1370  Iceland  2004               83.88    45380.965464
# 843   Denmark  2004               80.93    50566.988088
# 2285   Norway  2004               77.69    59647.501415
# 1042  Finland  2004               72.39    43725.599663

# %%
top_5_gdp_2014 = gdp_and_internet_2014.sort_values('GDP_Per_Capita', ascending=False).head(5)
top_5_gdp_2014

# %%
top_5_gdp_2004 = gdp_and_internet_2004.sort_values('GDP_Per_Capita', ascending=False).head(5)
top_5_gdp_2004

# %%
top_5_gdp_2009 = gdp_and_internet_2009.sort_values('GDP_Per_Capita', ascending=False).head(5)
top_5_gdp_2009

# %%
top_five_internet=
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-25a1058184f0> in <module>
# ----> 1 top_five_internet
#
# NameError: name 'top_five_internet' is not defined
